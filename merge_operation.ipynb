# %%
from openalex_matching import rapidfuzz_match, get_unique_ids
import pandas as pd
from rapidfuzz import process, fuzz

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#extracted_references = pd.read_csv("./raw_data/extracted_references.csv")
extracted_references = pd.read_csv('./raw_data/AJS_1_teeger2023.pdf.txt', delimiter='\t')
openalex_works = pd.read_csv("./two_journals.csv")

# %%
openalex_works_list = list(openalex_works['concat_name_title'])

# %%
extracted_references_list = list(extracted_references.iloc[:,0])

# %%
import time
start_time = time.time()



matched_df = rapidfuzz_match(extracted_references=extracted_references_list, openalex_works = openalex_works_list, scorer=fuzz.token_sort_ratio)



end_time = time.time()
print(f"Time taken: {end_time - start_time} seconds")
# Out:
# Time taken: 8.028951644897461 seconds

# %%
matched_df_oa = get_unique_ids(matched_df, openalex_works, 'id')

# %%
matched_df_oa.sort_values(by='top_scores', ascending=False)
# Out:
#                                    extracted_reference  \
# 38   fine-gary-alan-1996-reputational-entrepreneurs...
# 10   binder-amy-j-2009-contentious-curricula-afroce...
# 114  stein-arlene-2014-reluctant-witnesses-survivor...
# 6    bell-joyce-m-and-douglas-hartmann-2007-diversi...
# 18   brustein-william-i-2003-roots-of-hate-anti-sem...
# ..                                                 ...
# 31                                         23-4-548-62
# 77                                           56-122-26
# 57                                             1403-15
# 29                                            18799377
# 16                                                 108
#
#                                              top_match  \
# 38   (fine-reputational-entrepreneurs-and-the-memor...
# 10   (yamane-contentious-curricula-afrocentrism-and...
# 114  (wolf-reluctant-witnesses-survivors-their-chil...
# 6    (bell-diversity-in-everyday-discourse-the-cult...
# 18   (olick-roots-of-hate-anti-semitism-in-europe-b...
# ..                                                 ...
# 31   (-volume-74-numbers-1-6, 30.303030303030297, 3...
# 77      (dintenfass-525-527, 29.629629629629626, 7200)
# 57   (waite-working-wives-1940-1960, 27.77777777777...
# 29   (kohn-england-1870-1914, 26.66666666666667, 40...
# 16   (-index-to-volume-108, 26.086956521739136, 25439)
#
#                                              top_names  top_scores  \
# 38   fine-reputational-entrepreneurs-and-the-memory...   91.608392
# 10   yamane-contentious-curricula-afrocentrism-and-...   81.208054
# 114  wolf-reluctant-witnesses-survivors-their-child...   78.200692
# 6    bell-diversity-in-everyday-discourse-the-cultu...   76.666667
# 18   olick-roots-of-hate-anti-semitism-in-europe-be...   76.264591
# ..                                                 ...         ...
# 31                              -volume-74-numbers-1-6   30.303030
# 77                                  dintenfass-525-527   29.629630
# 57                       waite-working-wives-1940-1960   27.777778
# 29                              kohn-england-1870-1914   26.666667
# 16                                -index-to-volume-108   26.086957
#
#      top_indexes                                       second_match  \
# 38           594  (anderson-policy-entrepreneurs-and-the-origins...
# 10         13939  (goodwin-review-of-timothy-p-wickham-crowley-s...
# 114        22631  (silverstein-law-and-the-language-of-identity-...
# 6          28152  (jacobs-the-torment-of-secrecy-the-background-...
# 18         21365  (goodwin-review-of-pierre-birnbaum-s-states-an...
# ..           ...                                                ...
# 31         39456  (-albion-woodbury-small-1854-1926, 27.90697674...
# 77          7200  (-volume-74-numbers-1-6, 25.806451612903224, 3...
# 57         29980  (kohn-england-1870-1914, 27.586206896551722, 4...
# 29         40153  (manheim-karl-mannheim-1893-1947, 25.641025641...
# 16         25439  (-contents-of-volume-108, 23.076923076923073, ...
#
#                                            third_match  \
# 38   (warikoo-addressing-emotional-health-while-pro...
# 10   (bin-the-contentious-public-sphere-law-media-a...
# 114  (rueschemeyer-the-rise-of-the-rest-challenges-...
# 6    (lasswell-the-torment-of-secrecy-the-backgroun...
# 18   (monson-the-politics-of-child-support-in-ameri...
# ..                                                 ...
# 31   (parsons-sociology-1941-46, 27.77777777777778,...
# 77   (brown-asr-2010-to-2012, 25.806451612903224, 4...
# 57   (brown-asr-2010-to-2012, 27.586206896551722, 4...
# 29   (-obituary-havelock-ellis-1859-1939, 23.809523...
# 16   (-index-to-volume-110, 17.391304347826086, 23858)
#
#                          openalex_ids
# 38   https://openalex.org/W2015298379
# 10   https://openalex.org/W2510360353
# 114  https://openalex.org/W2774026818
# 6    https://openalex.org/W2110729564
# 18   https://openalex.org/W2517610182
# ..                                ...
# 31   https://openalex.org/W4205681499
# 77   https://openalex.org/W4245888241
# 57   https://openalex.org/W1978487604
# 29   https://openalex.org/W4248521117
# 16   https://openalex.org/W4242102195
#
# [152 rows x 8 columns]
